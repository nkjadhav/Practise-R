# %% [markdown]
# # Time Series
# Prediction in future is known as Forcasting - x axis time and y axis prediction
# - Trends (Consistent Increasing or Decreasing)
# - Season (Pattern related to time of week/month/quarter/year/festival)
# - Cycles (Patterns that are beyond a year, only seen in dataset having lots of years of data)
# - Irregulr patterns are error

# %% [markdown]
# ## Types
# - Additive Time Series
# - Multiplicative Time Series

# %% [markdown]
# Moving Average - Avg of moving set of points is calculated and curve is fitted along with avg points.
#
# Exponential Smoothing - Nearest pt. gets higher weightage while fitting curve

# %% [markdown]
# ## Error Analysis
# - MAPE - Mean Absolute Percentage Error
# - MAD - Mean Absolute Deviaton
# - MSD - Mean Squared Deviation

# %%
library(quantmod)
library(forecast)
library(fpp)
# Out:
# Loading required package: xts
# Loading required package: zoo
#
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Loading required package: TTR
# Version 0.4-0 included new data defaults. See ?getSymbols.
# Loading required package: fma
# Loading required package: expsmooth
# Loading required package: lmtest
# Loading required package: tseries

# %%
# Loading Google stock data using NASDAQ (GOOG)
from.dat <- as.Date("04/01/14", format = "%m/%d/%y")
to.dat <- as.Date("10/30/17", format = "%m/%d/%y")
getSymbols("GOOG", src = "yahoo", from = from.dat, to = to.dat)
head(GOOG)
# Out:
# 'getSymbols' currently uses auto.assign=TRUE by default, but will
# use auto.assign=FALSE in 0.5-0. You will still be able to use
# 'loadSymbols' to automatically load data. getOption("getSymbols.env")
# and getOption("getSymbols.auto.assign") will still be checked for
# alternate defaults.
#
# This message is shown once per session and may be disabled by setting
# options("getSymbols.warning4.0"=FALSE). See ?getSymbols for details.
#
#
# WARNING: There have been significant changes to Yahoo Finance data.
# Please see the Warning section of '?getSymbols.yahoo' for details.
#
# This message is shown once per session and may be disabled by setting
# options("getSymbols.yahoo.warning"=FALSE).
# [1] "GOOG"
#            GOOG.Open GOOG.High GOOG.Low GOOG.Close GOOG.Volume GOOG.Adjusted
# 2014-04-01  555.6547  565.3414 555.6547   564.0585        7900      564.0585
# 2014-04-02  596.7090  601.5225 559.1157   563.8994      147500      563.8994
# 2014-04-03  566.7338  584.0685 561.0450   566.6244     5113100      566.6244
# 2014-04-04  571.5076  574.6105 540.0306   540.1699     6386800      540.1699
# 2014-04-07  537.7830  545.4807 524.2673   535.2072     4413700      535.2072
# 2014-04-08  539.6328  551.9650 538.6482   551.8655     3159900      551.8655

# %%
# Converting to monthly stocks
mGoog <- to.monthly(GOOG)
head(mGoog)
# Out:
#          GOOG.Open GOOG.High GOOG.Low GOOG.Close GOOG.Volume GOOG.Adjusted
# Apr 2014  555.6547  601.5225 500.0504   523.7800    67539600      523.7800
# May 2014  524.2275  564.7348 500.5477   556.8282    36727500      556.8282
# Jun 2014  557.6339  579.2649 535.8038   572.1341    38105800      572.1341
# Jul 2014  575.1575  596.3709 561.9203   568.4742    34704900      568.4742
# Aug 2014  567.2808  584.1282 556.9377   568.4742    27734000      568.4742
# Sep 2014  568.7228  593.2181 565.1028   574.2027    33608300      574.2027

# %%
googOpen <- Op(mGoog)
googOpen
# Out:
#          GOOG.Open
# Apr 2014  555.6547
# May 2014  524.2275
# Jun 2014  557.6339
# Jul 2014  575.1575
# Aug 2014  567.2808
# Sep 2014  568.7228
# Oct 2014  572.8601
# Nov 2014  552.4623
# Dec 2014  535.9531
# Jan 2015  526.1147
# Feb 2015  528.8199
# Mar 2015  557.4623
# Apr 2015  545.5975
# May 2015  538.4300
# Jun 2015  536.7900
# Jul 2015  524.7300
# Aug 2015  625.3400
# Sep 2015  602.3600
# Oct 2015  608.3700
# Nov 2015  711.0600
# Dec 2015  747.1100
# Jan 2016  743.0000
# Feb 2016  750.4600
# Mar 2016  703.6200
# Apr 2016  738.6000
# May 2016  697.6300
# Jun 2016  734.5300
# Jul 2016  692.2000
# Aug 2016  761.0900
# Sep 2016  769.2500
# Oct 2016  774.2500
# Nov 2016  782.8900
# Dec 2016  757.4400
# Jan 2017  778.8100
# Feb 2017  799.6800
# Mar 2017  828.8500
# Apr 2017  829.2200
# May 2017  901.9400
# Jun 2017  968.9500
# Jul 2017  912.1800
# Aug 2017  932.3800
# Sep 2017  941.1300
# Oct 2017  959.9800

# %%
# Creating timeseries
ts1 <- ts(googOpen, frequency = 12)
ts1
# Out:
#        Jan      Feb      Mar      Apr      May      Jun      Jul      Aug
# 1 555.6547 524.2275 557.6339 575.1575 567.2808 568.7228 572.8601 552.4623
# 2 545.5975 538.4300 536.7900 524.7300 625.3400 602.3600 608.3700 711.0600
# 3 738.6000 697.6300 734.5300 692.2000 761.0900 769.2500 774.2500 782.8900
# 4 829.2200 901.9400 968.9500 912.1800 932.3800 941.1300 959.9800
#        Sep      Oct      Nov      Dec
# 1 535.9531 526.1147 528.8199 557.4623
# 2 747.1100 743.0000 750.4600 703.6200
# 3 757.4400 778.8100 799.6800 828.8500
# 4

# %%
# plot time series
plot(ts1, xlab = "Year+1", ylab = "GOOG")
# Out:
# plot without title

# %%
# Decompose the time series
plot(decompose(ts1), xlab = "Years+1")
# Out:
# plot without title

# %%
# Training and Testing Data

# %%
ts1Train<-window(ts1,start=1,end=3.5)
plot(ts1Train)
# Out:
# plot without title

# %%
ts1Test<-window(ts1,start=3.5,end=4.5)
plot(ts1Test)
# Out:
# plot without title

# %%
# Forcasting using simple moving average
# For univariate time series
# ETS(A,A,N)
plot(ts1)

goog_ma<-ma(ts1Train, order = 3)
goog_ma_forecast<-forecast(goog_ma)
lines(goog_ma_forecast$fitted, col="red")
lines(goog_ma_forecast$mean, col="blue")

goog_ma<-ma(ts1Train, order = 4)
goog_ma_forecast<-forecast(goog_ma)
lines(goog_ma_forecast$fitted, col="blue")
lines(goog_ma_forecast$mean, col="yellow")

goog_ma<-ma(ts1Train, order = 10)
goog_ma_forecast<-forecast(goog_ma)
lines(goog_ma_forecast$fitted, col="green")
lines(goog_ma_forecast$mean, col="orange")
# Out:
# Warning message in ets(object, lambda = lambda, biasadj = biasadj, allow.multiplicative.trend = allow.multiplicative.trend, :
# "Missing values encountered. Using longest contiguous portion of time series"Warning message in ets(object, lambda = lambda, biasadj = biasadj, allow.multiplicative.trend = allow.multiplicative.trend, :
# "Missing values encountered. Using longest contiguous portion of time series"Warning message in ets(object, lambda = lambda, biasadj = biasadj, allow.multiplicative.trend = allow.multiplicative.trend, :
# "Missing values encountered. Using longest contiguous portion of time series"
# plot without title

# %%
plot(goog_ma_forecast)
lines(ts1Test)
# Out:
# Plot with title "Forecasts from ETS(A,A,N)"

# %%
# Simple exponential smoothing model for short term foecasting
fit<-ses(ts1Train, h=10, alpha = 0.9)
plot(fit)
lines(ts1Test, col="red")
summary(fit)
# Out:
# Forecast method: Simple exponential smoothing
#
# Model Information:
# Simple exponential smoothing
#
# Call:
#  ses(y = ts1Train, h = 10, alpha = 0.9)
#
#   Smoothing parameters:
#     alpha = 0.9
#
#   Initial states:
#     l = 552.8499
#
#   sigma:  36.6177
#
#      AIC     AICc      BIC
# 331.6191 332.0476 334.4870
#
# Error measures:
#                    ME     RMSE      MAE      MPE     MAPE      MASE       ACF1
# Training set 7.912314 35.41674 24.36553 1.039082 3.748349 0.1959052 -0.1701282
#
# Forecasts:
#       Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# Aug 3       773.6034 726.6760 820.5308 701.8341 845.3727
# Sep 3       773.6034 710.4690 836.7378 677.0477 870.1591
# Oct 3       773.6034 697.6448 849.5621 657.4347 889.7721
# Nov 3       773.6034 686.6926 860.5142 640.6849 906.5220
# Dec 3       773.6034 676.9740 870.2329 625.8214 921.3854
# Jan 4       773.6034 668.1472 879.0596 612.3220 934.8848
# Feb 4       773.6034 660.0042 887.2026 599.8684 947.3384
# Mar 4       773.6034 652.4071 894.7997 588.2496 958.9572
# Apr 4       773.6034 645.2589 901.9479 577.3174 969.8894
# May 4       773.6034 638.4883 908.7185 566.9627 980.2441
# Plot with title "Forecasts from Simple exponential smoothing"

# %%
# Double exponentil smoothing model
# Holt local trend method (Level and Trend)
fit<-holt(ts1Train, h=10)
plot(fit)
lines(ts1Test, col = "red")
# Out:
# Plot with title "Forecasts from Holt's method"

# %%
fit<-holt(ts1Train, h=10, alpha = 0.9, beta = 0.9)
plot(fit)
# Out:
# Plot with title "Forecasts from Holt's method"

# %% [markdown]
# # ETS - Error Trend Season
# A - Additive
#
# M - Multiplicative
#
# Z - Automatic

# %%
ets1<-ets(ts1Train, model = "AAN") # fit model
fcast<-forecast(ets1) #forcast on ets
plot(fcast)
lines(ts1Test, col="red")
fcast
# Out:
#       Point Forecast    Lo 80     Hi 80    Lo 95     Hi 95
# Aug 3       782.0176 735.2365  828.7987 710.4720  853.5632
# Sep 3       789.8453 731.2236  848.4670 700.1912  879.4994
# Oct 3       797.6730 729.2270  866.1190 692.9938  902.3521
# Nov 3       805.5007 728.4712  882.5302 687.6942  923.3072
# Dec 3       813.3284 728.5783  898.0784 683.7144  942.9423
# Jan 4       821.1561 729.3306  912.9815 680.7211  961.5910
# Feb 4       828.9837 730.5886  927.3789 678.5014  979.4661
# Mar 4       836.8114 732.2571  941.3658 676.9094  996.7135
# Apr 4       844.6391 734.2672  955.0110 675.8399 1013.4384
# May 4       852.4668 736.5676  968.3660 675.2143 1029.7194
# Jun 4       860.2945 739.1185  981.4705 674.9718 1045.6173
# Jul 4       868.1222 741.8884  994.3560 675.0643 1061.1801
# Aug 4       875.9499 744.8521 1007.0477 675.4531 1076.4467
# Sep 4       883.7776 747.9887 1019.5665 676.1063 1091.4488
# Oct 4       891.6053 751.2808 1031.9298 676.9975 1106.2131
# Nov 4       899.4330 754.7139 1044.1521 678.1042 1120.7618
# Dec 4       907.2607 758.2754 1056.2459 679.4073 1135.1140
# Jan 5       915.0884 761.9546 1068.2221 680.8905 1149.2862
# Feb 5       922.9160 765.7423 1080.0898 682.5395 1163.2926
# Mar 5       930.7437 769.6302 1091.8573 684.3418 1177.1456
# Apr 5       938.5714 773.6111 1103.5317 686.2864 1190.8564
# May 5       946.3991 777.6788 1115.1194 688.3637 1204.4346
# Jun 5       954.2268 781.8275 1126.6261 690.5648 1217.8888
# Jul 5       962.0545 786.0521 1138.0569 692.8821 1231.2269
# Plot with title "Forecasts from ETS(A,A,N)"

# %%
accuracy(fcast, ts1Test)
# Out:
#              ME         RMSE     MAE      MPE        MAPE     MASE
# Training set -0.6450783 34.06713 24.89573 -0.3813807 3.946216 0.2001681
# Test set     41.0509277 64.83944 50.56575  4.2823038 5.520332 0.4065618
#              ACF1        Theil's U
# Training set -0.02434065       NA
# Test set      0.69680940 1.692278
